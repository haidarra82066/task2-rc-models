# %% [markdown]
# # Task 2 — R-C Building Thermal Modelling (index)
#
# This task is split into one notebook per question so no single file gets too large:
#
# - **Question 1 — data analysis & concept drift:** `task2_Q1_data_analysis.ipynb`
# - **Question 2 — R-C model hierarchy (A/B/C):** `task2_Q2_rc_models.ipynb`
# - **Question 3 — multi-horizon evaluation on year 2:** `task2_Q3_evaluation.ipynb`
#
# Each notebook is standalone (it reloads the data and, where needed, refits the models). Figures are saved to `../figures/` as interactive HTML and static PNG.
